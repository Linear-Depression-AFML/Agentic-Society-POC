# %%
import sender_reciever as sr
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(columns=["Game", "Start Sender Amount", "Start Receiver Amount", "Amount Sent By Sender", "Amount Sent By Receiver", "Final Sender Amount", "Final Receiver Amount"])
s_wins = 0
r_wins = 0
ties = 0
game_fails = 0
rounds = 10
for i in range(100):
    try:
        result = sr.run_game(15, i+1, df, rounds)
        if result == 1:
            s_wins += 1
        elif result == -1:
            r_wins += 1
        else:
            ties += 1
    except Exception as e:
        print(f"Error in game {i+1}: {e}")
        game_fails += 1
        
    print(df)
    
df.to_csv("sr_games_15m_10r.csv", index=False)
# Out:
# === Game 1 ===
# Round 1:
# Sender's account: 15, Receiver's account: 0
# Amount sent by sender: 7, Amount sent back by receiver: 2
# Sender's account: 10, Receiver's account: 12
#
#
# Round 2:
# Sender's account: 10, Receiver's account: 12
# Amount sent by sender: 5, Amount sent back by receiver: 2
# Sender's account: 7, Receiver's account: 20
#
#
# Round 3:
# Sender's account: 7, Receiver's account: 20
# Amount sent by sender: 5, Amount sent back by receiver: 5
# Sender's account: 7, Receiver's account: 25
#
#
# Round 4:
# Sender's account: 7, Receiver's account: 25
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 7, Receiver's account: 26
#
#
# Round 5:
# Sender's account: 7, Receiver's account: 26
# Amount sent by sender: 3, Amount sent back by receiver: 1
# Sender's account: 5, Receiver's account: 31
#
#
# Round 6:
# Sender's account: 5, Receiver's account: 31
# Amount sent by sender: 2, Amount sent back by receiver: 2
# Sender's account: 5, Receiver's account: 33
#
#
# Round 7:
# Sender's account: 5, Receiver's account: 33
# Amount sent by sender: 2, Amount sent back by receiver: 1
# Sender's account: 4, Receiver's account: 36
#
#
# Round 8:
# Sender's account: 4, Receiver's account: 36
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 4, Receiver's account: 37
#
#
# Round 9:
# Sender's account: 4, Receiver's account: 37
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 4, Receiver's account: 37
#
#
# Round 10:
# Sender's account: 4, Receiver's account: 37
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 4, Receiver's account: 38
#
#
#     Game  Start Sender Amount  Start Receiver Amount  Amount Sent By Sender  \
# 1    1.0                 15.0                    0.0                    7.0
# 2    1.0                 10.0                   12.0                    5.0
# 3    1.0                  7.0                   20.0                    5.0
# 4    1.0                  7.0                   25.0                    1.0
# 5    1.0                  7.0                   26.0                    3.0
# 6    1.0                  5.0                   31.0                    2.0
# 7    1.0                  5.0                   33.0                    2.0
# 8    1.0                  4.0                   36.0                    1.0
# 9    1.0                  4.0                   37.0                    0.0
# 10   1.0                  4.0                   37.0                    1.0
#
#     Amount Sent By Receiver  Final Sender Amount  Final Receiver Amount
# 1                       2.0                 10.0                   12.0
# 2                       2.0                  7.0                   20.0
# 3                       5.0                  7.0                   25.0
# 4                       1.0                  7.0                   26.0
# 5                       1.0                  5.0                   31.0
# 6                       2.0                  5.0                   33.0
# 7                       1.0                  4.0                   36.0
# 8                       1.0                  4.0                   37.0
# 9                       0.0                  4.0                   37.0
# 10                      1.0                  4.0                   38.0
#
# === Game 2 ===
# Round 1:
# Sender's account: 15, Receiver's account: 0
# Amount sent by sender: 3, Amount sent back by receiver: 3
# Sender's account: 15, Receiver's account: 3
#
#
# Round 2:
# Sender's account: 15, Receiver's account: 3
# Amount sent by sender: 9, Amount sent back by receiver: 6
# Sender's account: 12, Receiver's account: 15
#
#
# Round 3:
# Sender's account: 12, Receiver's account: 15
# Amount sent by sender: 4, Amount sent back by receiver: 3
# Sender's account: 11, Receiver's account: 20
#
#
# Round 4:
# Sender's account: 11, Receiver's account: 20
# Amount sent by sender: 5, Amount sent back by receiver: 5
# Sender's account: 11, Receiver's account: 25
#
#
# Round 5:
# Sender's account: 11, Receiver's account: 25
# Amount sent by sender: 4, Amount sent back by receiver: 0
# Sender's account: 7, Receiver's account: 33
#
#
# Round 6:
# Sender's account: 7, Receiver's account: 33
# Amount sent by sender: 5, Amount sent back by receiver: 0
# Sender's account: 2, Receiver's account: 43
#
#
# Round 7:
# Sender's account: 2, Receiver's account: 43
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 2, Receiver's account: 44
#
#
# Round 8:
# Sender's account: 2, Receiver's account: 44
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 2, Receiver's account: 45
#
#
# Round 9:
# Sender's account: 2, Receiver's account: 45
# Amount sent by sender: 2, Amount sent back by receiver: 0
# Sender's account: 0, Receiver's account: 49
#
#
# Round 10:
# Sender's account: 0, Receiver's account: 49
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 0, Receiver's account: 49
#
#
#     Game  Start Sender Amount  Start Receiver Amount  Amount Sent By Sender  \
# 1    1.0                 15.0                    0.0                    7.0
# 2    1.0                 10.0                   12.0                    5.0
# 3    1.0                  7.0                   20.0                    5.0
# 4    1.0                  7.0                   25.0                    1.0
# 5    1.0                  7.0                   26.0                    3.0
# 6    1.0                  5.0                   31.0                    2.0
# 7    1.0                  5.0                   33.0                    2.0
# 8    1.0                  4.0                   36.0                    1.0
# 9    1.0                  4.0                   37.0                    0.0
# 10   1.0                  4.0                   37.0                    1.0
# 11   2.0                 15.0                    0.0                    3.0
# 12   2.0                 15.0                    3.0                    9.0
# 13   2.0                 12.0                   15.0                    4.0
# 14   2.0                 11.0                   20.0                    5.0
# 15   2.0                 11.0                   25.0                    4.0
# 16   2.0                  7.0                   33.0                    5.0
# 17   2.0                  2.0                   43.0                    1.0
# 18   2.0                  2.0                   44.0                    1.0
# 19   2.0                  2.0                   45.0                    2.0
# 20   2.0                  0.0                   49.0                    0.0
#
#     Amount Sent By Receiver  Final Sender Amount  Final Receiver Amount
# 1                       2.0                 10.0                   12.0
# 2                       2.0                  7.0                   20.0
# 3                       5.0                  7.0                   25.0
# 4                       1.0                  7.0                   26.0
# 5                       1.0                  5.0                   31.0
# 6                       2.0                  5.0                   33.0
# 7                       1.0                  4.0                   36.0
# 8                       1.0                  4.0                   37.0
# 9                       0.0                  4.0                   37.0
# 10                      1.0                  4.0                   38.0
# 11                      3.0                 15.0                    3.0
# 12                      6.0                 12.0                   15.0
# 13                      3.0                 11.0                   20.0
# 14                      5.0                 11.0                   25.0
# 15                      0.0                  7.0                   33.0
# 16                      0.0                  2.0                   43.0
# 17                      1.0                  2.0                   44.0
# 18                      1.0                  2.0                   45.0
# 19                      0.0                  0.0                   49.0
# 20                      0.0                  0.0                   49.0
#
# === Game 3 ===
# Round 1:
# Sender's account: 15, Receiver's account: 0
# Amount sent by sender: 7, Amount sent back by receiver: 7
# Sender's account: 15, Receiver's account: 7
#
#
# Round 2:
# Sender's account: 15, Receiver's account: 7
# Amount sent by sender: 2, Amount sent back by receiver: 1
# Sender's account: 14, Receiver's account: 10
#
#
# Round 3:
# Sender's account: 14, Receiver's account: 10
# Amount sent by sender: 6, Amount sent back by receiver: 2
# Sender's account: 10, Receiver's account: 20
#
#
# Round 4:
# Sender's account: 10, Receiver's account: 20
# Amount sent by sender: 5, Amount sent back by receiver: 5
# Sender's account: 10, Receiver's account: 25
#
#
# Round 5:
# Sender's account: 10, Receiver's account: 25
# Amount sent by sender: 4, Amount sent back by receiver: 2
# Sender's account: 8, Receiver's account: 31
#
#
# Round 6:
# Sender's account: 8, Receiver's account: 31
# Amount sent by sender: 7, Amount sent back by receiver: 6
# Sender's account: 7, Receiver's account: 39
#
#
# Round 7:
# Sender's account: 7, Receiver's account: 39
# Amount sent by sender: 2, Amount sent back by receiver: 1
# Sender's account: 6, Receiver's account: 42
#
#
# Round 8:
# Sender's account: 6, Receiver's account: 42
# Amount sent by sender: 3, Amount sent back by receiver: 0
# Sender's account: 3, Receiver's account: 48
#
#
# Round 9:
# Sender's account: 3, Receiver's account: 48
# Amount sent by sender: 2, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 52
#
#
# Round 10:
# Sender's account: 1, Receiver's account: 52
# Amount sent by sender: 1, Amount sent back by receiver: 0
# Sender's account: 0, Receiver's account: 54
#
#
#     Game  Start Sender Amount  Start Receiver Amount  Amount Sent By Sender  \
# 1    1.0                 15.0                    0.0                    7.0
# 2    1.0                 10.0                   12.0                    5.0
# 3    1.0                  7.0                   20.0                    5.0
# 4    1.0                  7.0                   25.0                    1.0
# 5    1.0                  7.0                   26.0                    3.0
# 6    1.0                  5.0                   31.0                    2.0
# 7    1.0                  5.0                   33.0                    2.0
# 8    1.0                  4.0                   36.0                    1.0
# 9    1.0                  4.0                   37.0                    0.0
# 10   1.0                  4.0                   37.0                    1.0
# 11   2.0                 15.0                    0.0                    3.0
# 12   2.0                 15.0                    3.0                    9.0
# 13   2.0                 12.0                   15.0                    4.0
# 14   2.0                 11.0                   20.0                    5.0
# 15   2.0                 11.0                   25.0                    4.0
# 16   2.0                  7.0                   33.0                    5.0
# 17   2.0                  2.0                   43.0                    1.0
# 18   2.0                  2.0                   44.0                    1.0
# 19   2.0                  2.0                   45.0                    2.0
# 20   2.0                  0.0                   49.0                    0.0
# 21   3.0                 15.0                    0.0                    7.0
# 22   3.0                 15.0                    7.0                    2.0
# 23   3.0                 14.0                   10.0                    6.0
# 24   3.0                 10.0                   20.0                    5.0
# 25   3.0                 10.0                   25.0                    4.0
# 26   3.0                  8.0                   31.0                    7.0
# 27   3.0                  7.0                   39.0                    2.0
# 28   3.0                  6.0                   42.0                    3.0
# 29   3.0                  3.0                   48.0                    2.0
# 30   3.0                  1.0                   52.0                    1.0
#
#     Amount Sent By Receiver  Final Sender Amount  Final Receiver Amount
# 1                       2.0                 10.0                   12.0
# 2                       2.0                  7.0                   20.0
# 3                       5.0                  7.0                   25.0
# 4                       1.0                  7.0                   26.0
# 5                       1.0                  5.0                   31.0
# 6                       2.0                  5.0                   33.0
# 7                       1.0                  4.0                   36.0
# 8                       1.0                  4.0                   37.0
# 9                       0.0                  4.0                   37.0
# 10                      1.0                  4.0                   38.0
# 11                      3.0                 15.0                    3.0
# 12                      6.0                 12.0                   15.0
# 13                      3.0                 11.0                   20.0
# 14                      5.0                 11.0                   25.0
# 15                      0.0                  7.0                   33.0
# 16                      0.0                  2.0                   43.0
# 17                      1.0                  2.0                   44.0
# 18                      1.0                  2.0                   45.0
# 19                      0.0                  0.0                   49.0
# 20                      0.0                  0.0                   49.0
# 21                      7.0                 15.0                    7.0
# 22                      1.0                 14.0                   10.0
# 23                      2.0                 10.0                   20.0
# 24                      5.0                 10.0                   25.0
# 25                      2.0                  8.0                   31.0
# 26                      6.0                  7.0                   39.0
# 27                      1.0                  6.0                   42.0
# 28                      0.0                  3.0                   48.0
# 29                      0.0                  1.0                   52.0
# 30                      0.0                  0.0                   54.0
#
# === Game 4 ===
# Round 1:
# Sender's account: 15, Receiver's account: 0
# Amount sent by sender: 7, Amount sent back by receiver: 4
# Sender's account: 12, Receiver's account: 10
#
#
# Round 2:
# Sender's account: 12, Receiver's account: 10
# Amount sent by sender: 6, Amount sent back by receiver: 3
# Sender's account: 9, Receiver's account: 19
#
#
# Round 3:
# Sender's account: 9, Receiver's account: 19
# Amount sent by sender: 5, Amount sent back by receiver: 5
# Sender's account: 9, Receiver's account: 24
#
#
# Round 4:
# Sender's account: 9, Receiver's account: 24
# Amount sent by sender: 1, Amount sent back by receiver: 0
# Sender's account: 8, Receiver's account: 26
#
#
# Round 5:
# Sender's account: 8, Receiver's account: 26
# Amount sent by sender: 3, Amount sent back by receiver: 0
# Sender's account: 5, Receiver's account: 32
#
#
# Round 6:
# Sender's account: 5, Receiver's account: 32
# Amount sent by sender: 1, Amount sent back by receiver: 0
# Sender's account: 4, Receiver's account: 34
#
#
# Round 7:
# Sender's account: 4, Receiver's account: 34
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 4, Receiver's account: 35
#
#
# Round 8:
# Sender's account: 4, Receiver's account: 35
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 4, Receiver's account: 36
#
#
# Round 9:
# Sender's account: 4, Receiver's account: 36
# Amount sent by sender: 2, Amount sent back by receiver: 4
# 24                      5.0                 10.0                   25.0
# 25                      2.0                  8.0                   31.0
# 26                      6.0                  7.0                   39.0
# 27                      1.0                  6.0                   42.0
# 28                      0.0                  3.0                   48.0
# 29                      0.0                  1.0                   52.0
# 30                      0.0                  0.0                   54.0
# 31                      4.0                 12.0                   10.0
# 32                      3.0                  9.0                   19.0
# 33                      5.0                  9.0                   24.0
# 34                      0.0                  8.0                   26.0
# 35                      0.0                  5.0                   32.0
# 36                      0.0                  4.0                   34.0
# 37                      1.0                  4.0                   35.0
# 38                      1.0                  4.0                   36.0
# 39                      4.0                  6.0                   36.0
# 40                      1.0                  6.0                   37.0
#
# === Game 5 ===
# Round 1:
# Sender's account: 15, Receiver's account: 0
# Amount sent by sender: 8, Amount sent back by receiver: 2
# Sender's account: 9, Receiver's account: 14
#
#
# Round 2:
# Sender's account: 9, Receiver's account: 14
# Amount sent by sender: 5, Amount sent back by receiver: 5
# Sender's account: 9, Receiver's account: 19
#
#
# Round 3:
# Sender's account: 9, Receiver's account: 19
# Amount sent by sender: 5, Amount sent back by receiver: 5
# Sender's account: 9, Receiver's account: 24
#
#
# Round 4:
# Sender's account: 9, Receiver's account: 24
# Amount sent by sender: 3, Amount sent back by receiver: 1
# Sender's account: 7, Receiver's account: 29
#
#
# Round 5:
# Sender's account: 7, Receiver's account: 29
# Amount sent by sender: 6, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 41
#
#
# Round 6:
# Sender's account: 1, Receiver's account: 41
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 41
#
#
# Round 7:
# Sender's account: 1, Receiver's account: 41
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 41
#
#
# Round 8:
# Sender's account: 1, Receiver's account: 41
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 41
#
#
# Round 9:
# Sender's account: 1, Receiver's account: 41
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 41
#
#
# Round 10:
# Sender's account: 1, Receiver's account: 41
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 41
#
#
#     Game  Start Sender Amount  Start Receiver Amount  Amount Sent By Sender  \
# 1    1.0                 15.0                    0.0                    7.0
# 2    1.0                 10.0                   12.0                    5.0
# 3    1.0                  7.0                   20.0                    5.0
# 4    1.0                  7.0                   25.0                    1.0
# 5    1.0                  7.0                   26.0                    3.0
# 6    1.0                  5.0                   31.0                    2.0
# 7    1.0                  5.0                   33.0                    2.0
# 8    1.0                  4.0                   36.0                    1.0
# 9    1.0                  4.0                   37.0                    0.0
# 10   1.0                  4.0                   37.0                    1.0
# 11   2.0                 15.0                    0.0                    3.0
# 12   2.0                 15.0                    3.0                    9.0
# 13   2.0                 12.0                   15.0                    4.0
# 14   2.0                 11.0                   20.0                    5.0
# 15   2.0                 11.0                   25.0                    4.0
# 16   2.0                  7.0                   33.0                    5.0
# 39                      4.0                  6.0                   36.0
# 40                      1.0                  6.0                   37.0
# 41                      2.0                  9.0                   14.0
# 42                      5.0                  9.0                   19.0
# 43                      5.0                  9.0                   24.0
# 44                      1.0                  7.0                   29.0
# 45                      0.0                  1.0                   41.0
# 46                      0.0                  1.0                   41.0
# 47                      0.0                  1.0                   41.0
# 48                      0.0                  1.0                   41.0
# 49                      0.0                  1.0                   41.0
# 50                      0.0                  1.0                   41.0
#
# === Game 6 ===
# Round 1:
# Sender's account: 15, Receiver's account: 0
# Amount sent by sender: 5, Amount sent back by receiver: 3
# Sender's account: 13, Receiver's account: 7
#
#
# Round 2:
# Sender's account: 13, Receiver's account: 7
# Amount sent by sender: 5, Amount sent back by receiver: 0
# Sender's account: 8, Receiver's account: 17
#
#
# Round 3:
# Sender's account: 8, Receiver's account: 17
# Amount sent by sender: 2, Amount sent back by receiver: 2
# Sender's account: 8, Receiver's account: 19
#
#
# Round 4:
# Sender's account: 8, Receiver's account: 19
# Amount sent by sender: 4, Amount sent back by receiver: 3
# Sender's account: 7, Receiver's account: 24
#
#
# Round 5:
# Sender's account: 7, Receiver's account: 24
# Amount sent by sender: 3, Amount sent back by receiver: 3
# Sender's account: 7, Receiver's account: 27
#
#
# Round 6:
# Sender's account: 7, Receiver's account: 27
# Amount sent by sender: 5, Amount sent back by receiver: 0
# Sender's account: 2, Receiver's account: 37
#
#
# Round 7:
# Sender's account: 2, Receiver's account: 37
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 2, Receiver's account: 38
#
#
# Round 8:
# Sender's account: 2, Receiver's account: 38
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 2, Receiver's account: 39
#
#
# Round 9:
# Sender's account: 2, Receiver's account: 39
# Amount sent by sender: 1, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 41
#
#
# Round 10:
# Sender's account: 1, Receiver's account: 41
# Amount sent by sender: 1, Amount sent back by receiver: 0
# Sender's account: 0, Receiver's account: 43
#
#
#     Game  Start Sender Amount  Start Receiver Amount  Amount Sent By Sender  \
# 1    1.0                 15.0                    0.0                    7.0
# 2    1.0                 10.0                   12.0                    5.0
# 3    1.0                  7.0                   20.0                    5.0
# 4    1.0                  7.0                   25.0                    1.0
# 5    1.0                  7.0                   26.0                    3.0
# 6    1.0                  5.0                   31.0                    2.0
# 7    1.0                  5.0                   33.0                    2.0
# 8    1.0                  4.0                   36.0                    1.0
# 9    1.0                  4.0                   37.0                    0.0
# 10   1.0                  4.0                   37.0                    1.0
# 11   2.0                 15.0                    0.0                    3.0
# 12   2.0                 15.0                    3.0                    9.0
# 13   2.0                 12.0                   15.0                    4.0
# 14   2.0                 11.0                   20.0                    5.0
# 15   2.0                 11.0                   25.0                    4.0
# 16   2.0                  7.0                   33.0                    5.0
# 17   2.0                  2.0                   43.0                    1.0
# 18   2.0                  2.0                   44.0                    1.0
# 19   2.0                  2.0                   45.0                    2.0
# 20   2.0                  0.0                   49.0                    0.0
# 31                      4.0                 12.0                   10.0
# 32                      3.0                  9.0                   19.0
# 33                      5.0                  9.0                   24.0
# 34                      0.0                  8.0                   26.0
# 35                      0.0                  5.0                   32.0
# 36                      0.0                  4.0                   34.0
# 37                      1.0                  4.0                   35.0
# 38                      1.0                  4.0                   36.0
# 39                      4.0                  6.0                   36.0
# 40                      1.0                  6.0                   37.0
# 41                      2.0                  9.0                   14.0
# 42                      5.0                  9.0                   19.0
# 43                      5.0                  9.0                   24.0
# 44                      1.0                  7.0                   29.0
# 45                      0.0                  1.0                   41.0
# 46                      0.0                  1.0                   41.0
# 47                      0.0                  1.0                   41.0
# 48                      0.0                  1.0                   41.0
# 49                      0.0                  1.0                   41.0
# 50                      0.0                  1.0                   41.0
# 51                      3.0                 13.0                    7.0
# 52                      0.0                  8.0                   17.0
# 53                      2.0                  8.0                   19.0
# 54                      3.0                  7.0                   24.0
# 55                      3.0                  7.0                   27.0
# 56                      0.0                  2.0                   37.0
# 57                      1.0                  2.0                   38.0
# 58                      1.0                  2.0                   39.0
# 59                      0.0                  1.0                   41.0
# 60                      0.0                  0.0                   43.0
#
# === Game 7 ===
# Round 1:
# Sender's account: 15, Receiver's account: 0
# Amount sent by sender: 7, Amount sent back by receiver: 2
# Sender's account: 10, Receiver's account: 12
#
#
# Round 2:
# Sender's account: 10, Receiver's account: 12
# Amount sent by sender: 5, Amount sent back by receiver: 0
# Sender's account: 5, Receiver's account: 22
#
#
# Round 3:
# Sender's account: 5, Receiver's account: 22
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 5, Receiver's account: 23
#
#
# Round 4:
# Sender's account: 5, Receiver's account: 23
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 5, Receiver's account: 24
#
#
# Round 5:
# Sender's account: 5, Receiver's account: 24
# Amount sent by sender: 3, Amount sent back by receiver: 1
# Sender's account: 3, Receiver's account: 29
#
#
# Round 6:
# Sender's account: 3, Receiver's account: 29
# Amount sent by sender: 1, Amount sent back by receiver: 0
# Sender's account: 2, Receiver's account: 31
#
#
# Round 7:
# Sender's account: 2, Receiver's account: 31
# Amount sent by sender: 1, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 33
#
#
# Round 8:
# Sender's account: 1, Receiver's account: 33
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 33
#
#
# Round 9:
# Sender's account: 1, Receiver's account: 33
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 33
#
#
# Round 10:
# Sender's account: 1, Receiver's account: 33
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 33
#
#
#     Game  Start Sender Amount  Start Receiver Amount  Amount Sent By Sender  \
# 1    1.0                 15.0                    0.0                    7.0
# 2    1.0                 10.0                   12.0                    5.0
# 3    1.0                  7.0                   20.0                    5.0
# 4    1.0                  7.0                   25.0                    1.0
# 5    1.0                  7.0                   26.0                    3.0
# ..   ...                  ...                    ...                    ...
# 66   7.0                  3.0                   29.0                    1.0
# 67   7.0                  2.0                   31.0                    1.0
# 68   7.0                  1.0                   33.0                    0.0
# 69   7.0                  1.0                   33.0                    0.0
# 70   7.0                  1.0                   33.0                    0.0
#
#     Amount Sent By Receiver  Final Sender Amount  Final Receiver Amount
# 1                       2.0                 10.0                   12.0
# 2                       2.0                  7.0                   20.0
# 3                       5.0                  7.0                   25.0
# 4                       1.0                  7.0                   26.0
# 5                       1.0                  5.0                   31.0
# ..                      ...                  ...                    ...
# 66                      0.0                  2.0                   31.0
# 67                      0.0                  1.0                   33.0
# 68                      0.0                  1.0                   33.0
# 69                      0.0                  1.0                   33.0
# 70                      0.0                  1.0                   33.0
#
# [70 rows x 7 columns]
#
# === Game 8 ===
# Round 1:
# Sender's account: 15, Receiver's account: 0
# Amount sent by sender: 3, Amount sent back by receiver: 3
# Sender's account: 15, Receiver's account: 3
#
#
# Round 2:
# Sender's account: 15, Receiver's account: 3
# Amount sent by sender: 9, Amount sent back by receiver: 0
# Sender's account: 6, Receiver's account: 21
#
#
# Round 3:
# Sender's account: 6, Receiver's account: 21
# Amount sent by sender: 3, Amount sent back by receiver: 3
# Sender's account: 6, Receiver's account: 24
#
#
# Round 4:
# Sender's account: 6, Receiver's account: 24
# Amount sent by sender: 1, Amount sent back by receiver: 0
# Sender's account: 5, Receiver's account: 26
#
#
# Round 5:
# Sender's account: 5, Receiver's account: 26
# Amount sent by sender: 4, Amount sent back by receiver: 3
# Sender's account: 4, Receiver's account: 31
#
#
# Round 6:
# Sender's account: 4, Receiver's account: 31
# Amount sent by sender: 2, Amount sent back by receiver: 0
# Sender's account: 2, Receiver's account: 35
#
#
# Round 7:
# Sender's account: 2, Receiver's account: 35
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 2, Receiver's account: 36
#
#
# Round 8:
# Sender's account: 2, Receiver's account: 36
# Amount sent by sender: 1, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 38
#
#
# Round 9:
# Sender's account: 1, Receiver's account: 38
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 38
#
#
# Round 10:
# Sender's account: 1, Receiver's account: 38
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 38
#
#
#     Game  Start Sender Amount  Start Receiver Amount  Amount Sent By Sender  \
# 1    1.0                 15.0                    0.0                    7.0
# 2    1.0                 10.0                   12.0                    5.0
# 3    1.0                  7.0                   20.0                    5.0
# ...
# Sender's account: 2, Receiver's account: 35
#
#
#      Game  Start Sender Amount  Start Receiver Amount  Amount Sent By Sender  \
# 1     1.0                 15.0                    0.0                    7.0
# 2     1.0                 10.0                   12.0                    5.0
# 3     1.0                  7.0                   20.0                    5.0
# 4     1.0                  7.0                   25.0                    1.0
# 5     1.0                  7.0                   26.0                    3.0
# ..    ...                  ...                    ...                    ...
# 956  96.0                  2.0                   32.0                    1.0
# 957  96.0                  2.0                   33.0                    1.0
# 958  96.0                  1.0                   35.0                    0.0
# 959  96.0                  1.0                   35.0                    0.0
# 960  96.0                  1.0                   35.0                    1.0
#
#      Amount Sent By Receiver  Final Sender Amount  Final Receiver Amount
# 1                        2.0                 10.0                   12.0
# 2                        2.0                  7.0                   20.0
# 3                        5.0                  7.0                   25.0
# 4                        1.0                  7.0                   26.0
# 5                        1.0                  5.0                   31.0
# ..                       ...                  ...                    ...
# 956                      1.0                  2.0                   33.0
# 957                      0.0                  1.0                   35.0
# 958                      0.0                  1.0                   35.0
# 959                      0.0                  1.0                   35.0
# 960                      2.0                  2.0                   35.0
#
# [960 rows x 7 columns]
#
# === Game 97 ===
# Round 1:
# Sender's account: 15, Receiver's account: 0
# Amount sent by sender: 7, Amount sent back by receiver: 2
# Sender's account: 10, Receiver's account: 12
#
#
# Round 2:
# Sender's account: 10, Receiver's account: 12
# Amount sent by sender: 5, Amount sent back by receiver: 2
# Sender's account: 7, Receiver's account: 20
#
#
# Round 3:
# Sender's account: 7, Receiver's account: 20
# Amount sent by sender: 5, Amount sent back by receiver: 5
# Sender's account: 7, Receiver's account: 25
#
#
# Round 4:
# Sender's account: 7, Receiver's account: 25
# Amount sent by sender: 3, Amount sent back by receiver: 3
# Sender's account: 7, Receiver's account: 28
#
#
# Round 5:
# Sender's account: 7, Receiver's account: 28
# Amount sent by sender: 4, Amount sent back by receiver: 0
# Sender's account: 3, Receiver's account: 36
#
#
# Round 6:
# Sender's account: 3, Receiver's account: 36
# Amount sent by sender: 2, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 40
#
#
# Round 7:
# Sender's account: 1, Receiver's account: 40
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 40
#
#
# Round 8:
# Sender's account: 1, Receiver's account: 40
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 40
#
#
# Round 9:
# Sender's account: 1, Receiver's account: 40
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 1, Receiver's account: 41
#
#
# Round 10:
# Sender's account: 1, Receiver's account: 41
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 41
#
#
#      Game  Start Sender Amount  Start Receiver Amount  Amount Sent By Sender  \
# 1     1.0                 15.0                    0.0                    7.0
# 2     1.0                 10.0                   12.0                    5.0
# 3     1.0                  7.0                   20.0                    5.0
# 4     1.0                  7.0                   25.0                    1.0
# 5     1.0                  7.0                   26.0                    3.0
# ..    ...                  ...                    ...                    ...
# 966  97.0                  3.0                   36.0                    2.0
# 967  97.0                  1.0                   40.0                    0.0
# 968  97.0                  1.0                   40.0                    0.0
# 969  97.0                  1.0                   40.0                    1.0
# 970  97.0                  1.0                   41.0                    0.0
#
#      Amount Sent By Receiver  Final Sender Amount  Final Receiver Amount
# 1                        2.0                 10.0                   12.0
# 2                        2.0                  7.0                   20.0
# 3                        5.0                  7.0                   25.0
# 4                        1.0                  7.0                   26.0
# 5                        1.0                  5.0                   31.0
# ..                       ...                  ...                    ...
# 966                      0.0                  1.0                   40.0
# 967                      0.0                  1.0                   40.0
# 968                      0.0                  1.0                   40.0
# 969                      1.0                  1.0                   41.0
# 970                      0.0                  1.0                   41.0
#
# [970 rows x 7 columns]
#
# === Game 98 ===
# Round 1:
# Sender's account: 15, Receiver's account: 0
# Amount sent by sender: 4, Amount sent back by receiver: 2
# Sender's account: 13, Receiver's account: 6
#
#
# Round 2:
# Sender's account: 13, Receiver's account: 6
# Amount sent by sender: 5, Amount sent back by receiver: 2
# Sender's account: 10, Receiver's account: 14
#
#
# Round 3:
# Sender's account: 10, Receiver's account: 14
# Amount sent by sender: 5, Amount sent back by receiver: 2
# Sender's account: 7, Receiver's account: 22
#
#
# Round 4:
# Sender's account: 7, Receiver's account: 22
# Amount sent by sender: 4, Amount sent back by receiver: 0
# Sender's account: 3, Receiver's account: 30
#
#
# Round 5:
# Sender's account: 3, Receiver's account: 30
# Amount sent by sender: 2, Amount sent back by receiver: 1
# Sender's account: 2, Receiver's account: 33
#
#
# Round 6:
# Sender's account: 2, Receiver's account: 33
# Amount sent by sender: 1, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 35
#
#
# Round 7:
# Sender's account: 1, Receiver's account: 35
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 35
#
#
# Round 8:
# Sender's account: 1, Receiver's account: 35
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 35
#
#
# Round 9:
# Sender's account: 1, Receiver's account: 35
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 35
#
#
# Round 10:
# Sender's account: 1, Receiver's account: 35
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 1, Receiver's account: 36
#
#
#      Game  Start Sender Amount  Start Receiver Amount  Amount Sent By Sender  \
# 1     1.0                 15.0                    0.0                    7.0
# 2     1.0                 10.0                   12.0                    5.0
# 3     1.0                  7.0                   20.0                    5.0
# 4     1.0                  7.0                   25.0                    1.0
# 5     1.0                  7.0                   26.0                    3.0
# ..    ...                  ...                    ...                    ...
# 976  98.0                  2.0                   33.0                    1.0
# 977  98.0                  1.0                   35.0                    0.0
# 978  98.0                  1.0                   35.0                    0.0
# 979  98.0                  1.0                   35.0                    0.0
# 980  98.0                  1.0                   35.0                    1.0
#
#      Amount Sent By Receiver  Final Sender Amount  Final Receiver Amount
# 1                        2.0                 10.0                   12.0
# 2                        2.0                  7.0                   20.0
# 3                        5.0                  7.0                   25.0
# 4                        1.0                  7.0                   26.0
# 5                        1.0                  5.0                   31.0
# ..                       ...                  ...                    ...
# 976                      0.0                  1.0                   35.0
# 977                      0.0                  1.0                   35.0
# 978                      0.0                  1.0                   35.0
# 979                      0.0                  1.0                   35.0
# 980                      1.0                  1.0                   36.0
#
# [980 rows x 7 columns]
#
# === Game 99 ===
# Round 1:
# Sender's account: 15, Receiver's account: 0
# Amount sent by sender: 6, Amount sent back by receiver: 6
# Sender's account: 15, Receiver's account: 6
#
#
# Round 2:
# Sender's account: 15, Receiver's account: 6
# Amount sent by sender: 7, Amount sent back by receiver: 0
# Sender's account: 8, Receiver's account: 20
#
#
# Round 3:
# Sender's account: 8, Receiver's account: 20
# Amount sent by sender: 5, Amount sent back by receiver: 2
# Sender's account: 5, Receiver's account: 28
#
#
# Round 4:
# Sender's account: 5, Receiver's account: 28
# Amount sent by sender: 3, Amount sent back by receiver: 3
# Sender's account: 5, Receiver's account: 31
#
#
# Round 5:
# Sender's account: 5, Receiver's account: 31
# Amount sent by sender: 2, Amount sent back by receiver: 2
# Sender's account: 5, Receiver's account: 33
#
#
# Round 6:
# Sender's account: 5, Receiver's account: 33
# Amount sent by sender: 2, Amount sent back by receiver: 0
# Sender's account: 3, Receiver's account: 37
#
#
# Round 7:
# Sender's account: 3, Receiver's account: 37
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 3, Receiver's account: 38
#
#
# Round 8:
# Sender's account: 3, Receiver's account: 38
# Amount sent by sender: 1, Amount sent back by receiver: 1
# Sender's account: 3, Receiver's account: 39
#
#
# Round 9:
# Sender's account: 3, Receiver's account: 39
# Amount sent by sender: 2, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 43
#
#
# Round 10:
# Sender's account: 1, Receiver's account: 43
# Amount sent by sender: 1, Amount sent back by receiver: 2
# Sender's account: 2, Receiver's account: 43
#
#
#      Game  Start Sender Amount  Start Receiver Amount  Amount Sent By Sender  \
# 1     1.0                 15.0                    0.0                    7.0
# 2     1.0                 10.0                   12.0                    5.0
# 3     1.0                  7.0                   20.0                    5.0
# 4     1.0                  7.0                   25.0                    1.0
# 5     1.0                  7.0                   26.0                    3.0
# ..    ...                  ...                    ...                    ...
# 986  99.0                  5.0                   33.0                    2.0
# 987  99.0                  3.0                   37.0                    1.0
# 988  99.0                  3.0                   38.0                    1.0
# 989  99.0                  3.0                   39.0                    2.0
# 990  99.0                  1.0                   43.0                    1.0
#
#      Amount Sent By Receiver  Final Sender Amount  Final Receiver Amount
# 1                        2.0                 10.0                   12.0
# 2                        2.0                  7.0                   20.0
# 3                        5.0                  7.0                   25.0
# 4                        1.0                  7.0                   26.0
# 5                        1.0                  5.0                   31.0
# ..                       ...                  ...                    ...
# 986                      0.0                  3.0                   37.0
# 987                      1.0                  3.0                   38.0
# 988                      1.0                  3.0                   39.0
# 989                      0.0                  1.0                   43.0
# 990                      2.0                  2.0                   43.0
#
# [990 rows x 7 columns]
#
# === Game 100 ===
# Round 1:
# Sender's account: 15, Receiver's account: 0
# Amount sent by sender: 7, Amount sent back by receiver: 7
# Sender's account: 15, Receiver's account: 7
#
#
# Round 2:
# Sender's account: 15, Receiver's account: 7
# Amount sent by sender: 9, Amount sent back by receiver: 3
# Sender's account: 9, Receiver's account: 22
#
#
# Round 3:
# Sender's account: 9, Receiver's account: 22
# Amount sent by sender: 5, Amount sent back by receiver: 0
# Sender's account: 4, Receiver's account: 32
#
#
# Round 4:
# Sender's account: 4, Receiver's account: 32
# Amount sent by sender: 1, Amount sent back by receiver: 0
# Sender's account: 3, Receiver's account: 34
#
#
# Round 5:
# Sender's account: 3, Receiver's account: 34
# Amount sent by sender: 2, Amount sent back by receiver: 1
# Sender's account: 2, Receiver's account: 37
#
#
# Round 6:
# Sender's account: 2, Receiver's account: 37
# Amount sent by sender: 1, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 39
#
#
# Round 7:
# Sender's account: 1, Receiver's account: 39
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 39
#
#
# Round 8:
# Sender's account: 1, Receiver's account: 39
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 39
#
#
# Round 9:
# Sender's account: 1, Receiver's account: 39
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 39
#
#
# Round 10:
# Sender's account: 1, Receiver's account: 39
# Amount sent by sender: 0, Amount sent back by receiver: 0
# Sender's account: 1, Receiver's account: 39
#
#
#        Game  Start Sender Amount  Start Receiver Amount  \
# 1       1.0                 15.0                    0.0
# 2       1.0                 10.0                   12.0
# 3       1.0                  7.0                   20.0
# 4       1.0                  7.0                   25.0
# 5       1.0                  7.0                   26.0
# ...     ...                  ...                    ...
# 996   100.0                  2.0                   37.0
# 997   100.0                  1.0                   39.0
# 998   100.0                  1.0                   39.0
# 999   100.0                  1.0                   39.0
# 1000  100.0                  1.0                   39.0
#
#       Amount Sent By Sender  Amount Sent By Receiver  Final Sender Amount  \
# 1                       7.0                      2.0                 10.0
# 2                       5.0                      2.0                  7.0
# 3                       5.0                      5.0                  7.0
# 4                       1.0                      1.0                  7.0
# 5                       3.0                      1.0                  5.0
# ...                     ...                      ...                  ...
# 996                     1.0                      0.0                  1.0
# 997                     0.0                      0.0                  1.0
# 998                     0.0                      0.0                  1.0
# 999                     0.0                      0.0                  1.0
# 1000                    0.0                      0.0                  1.0
#
#       Final Receiver Amount
# 1                      12.0
# 2                      20.0
# 3                      25.0
# 4                      26.0
# 5                      31.0
# ...                     ...
# 996                    39.0
# 997                    39.0
# 998                    39.0
# 999                    39.0
# 1000                   39.0
#
# [1000 rows x 7 columns]

# %%
print("Sender wins:", s_wins, "Receiver wins:", r_wins, "Ties:", ties, "Game fails:", game_fails)
# Out:
# Sender wins: 0 Receiver wins: 100 Ties: 0 Game fails: 0

# %%
for i in range(0, len(df), 10):
    new_df = df.iloc[i:i+10]
    new_df = new_df.reset_index(drop=True)
    plt.plot(new_df["Final Sender Amount"])
    plt.xticks(range(10))
plt.title("Final Sender Amount over 100 Games")
plt.xlabel("Round")
plt.ylabel("Sender Amount")
plt.show()

# %%
for i in range(0, len(df), 10):
    new_df = df.iloc[i:i+10]
    new_df = new_df.reset_index(drop=True)
    plt.plot(new_df["Final Receiver Amount"])
    plt.xticks(range(10))
plt.title("Final Receiver Amount over 100 Games")
plt.xlabel("Round")
plt.ylabel("Receiver Amount")
plt.show()
